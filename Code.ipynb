# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns, numpy as np

# %%
data=pd.read_csv("churn.csv")

data
# Out:
#      state  account length  area code phone number international plan  \
# 0       KS             128        415     382-4657                 no
# 1       OH             107        415     371-7191                 no
# 2       NJ             137        415     358-1921                 no
# 3       OH              84        408     375-9999                yes
# 4       OK              75        415     330-6626                yes
# ...    ...             ...        ...          ...                ...
# 3328    AZ             192        415     414-4276                 no
# 3329    WV              68        415     370-3271                 no
# 3330    RI              28        510     328-8230                 no
# 3331    CT             184        510     364-6381                yes
# 3332    TN              74        415     400-4344                 no
#
#      voice mail plan  number vmail messages  total day minutes  \
# ...

# %%
data.isna().sum()
# Out:
# state                     0
# account length            0
# area code                 0
# phone number              0
# international plan        0
# voice mail plan           0
# number vmail messages     0
# total day minutes         0
# total day calls           0
# total day charge          0
# total eve minutes         0
# total eve calls           0
# total eve charge          0
# total night minutes       0
# total night calls         0
# total night charge        0
# total intl minutes        0
# total intl calls          0
# total intl charge         0
# customer service calls    0
# churn                     0
# dtype: int64

# %%
data['churn'].value_counts()
# Out:
# False    2850
# True      483
# Name: churn, dtype: int64

# %%
# %matplotlib inline

alpha_color=0.5

data['churn'].value_counts().plot(kind='bar')

# %%
data.dtypes
# Out:
# state                      object
# account length              int64
# area code                   int64
# phone number               object
# international plan         object
# voice mail plan            object
# number vmail messages       int64
# total day minutes         float64
# total day calls             int64
# total day charge          float64
# total eve minutes         float64
# total eve calls             int64
# total eve charge          float64
# total night minutes       float64
# total night calls           int64
# total night charge        float64
# total intl minutes        float64
# total intl calls            int64
# total intl charge         float64
# customer service calls      int64
# churn                        bool
# dtype: object

# %%
data.shape
# Out:
# (3333, 21)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 21 columns):
# state                     3333 non-null object
# account length            3333 non-null int64
# area code                 3333 non-null int64
# phone number              3333 non-null object
# international plan        3333 non-null object
# voice mail plan           3333 non-null object
# number vmail messages     3333 non-null int64
# total day minutes         3333 non-null float64
# total day calls           3333 non-null int64
# total day charge          3333 non-null float64
# total eve minutes         3333 non-null float64
# total eve calls           3333 non-null int64
# total eve charge          3333 non-null float64
# total night minutes       3333 non-null float64
# total night calls         3333 non-null int64
# total night charge        3333 non-null float64
# total intl minutes        3333 non-null float64
# total intl calls          3333 non-null int64
# ...

# %%
data.describe()
# Out:
#        account length    area code  number vmail messages  total day minutes  \
# count     3333.000000  3333.000000            3333.000000        3333.000000
# mean       101.064806   437.182418               8.099010         179.775098
# std         39.822106    42.371290              13.688365          54.467389
# min          1.000000   408.000000               0.000000           0.000000
# 25%         74.000000   408.000000               0.000000         143.700000
# 50%        101.000000   415.000000               0.000000         179.400000
# 75%        127.000000   510.000000              20.000000         216.400000
# max        243.000000   510.000000              51.000000         350.800000
#
#        total day calls  total day charge  total eve minutes  total eve calls  \
# count      3333.000000       3333.000000        3333.000000      3333.000000
# mean        100.435644         30.562307         200.980348       100.114311
# ...

# %%
data.corr().abs()
# Out:
#                         account length  area code  number vmail messages  \
# account length                1.000000   0.012463               0.004628
# area code                     0.012463   1.000000               0.001994
# number vmail messages         0.004628   0.001994               1.000000
# total day minutes             0.006216   0.008264               0.000778
# total day calls               0.038470   0.009646               0.009548
# total day charge              0.006214   0.008264               0.000776
# total eve minutes             0.006757   0.003580               0.017562
# total eve calls               0.019260   0.011886               0.005864
# total eve charge              0.006745   0.003607               0.017578
# total night minutes           0.008955   0.005825               0.007681
# total night calls             0.013176   0.016522               0.007123
# total night charge            0.008960   0.005845               0.007663
# ...

# %%
data.drop(['account length','area code'], axis=1).corr().abs()
# Out:
#                         number vmail messages  total day minutes  \
# number vmail messages                1.000000           0.000778
# total day minutes                    0.000778           1.000000
# total day calls                      0.009548           0.006750
# total day charge                     0.000776           1.000000
# total eve minutes                    0.017562           0.007043
# total eve calls                      0.005864           0.015769
# total eve charge                     0.017578           0.007029
# total night minutes                  0.007681           0.004323
# total night calls                    0.007123           0.022972
# total night charge                   0.007663           0.004300
# total intl minutes                   0.002856           0.010155
# total intl calls                     0.013957           0.008033
# total intl charge                    0.002884           0.010092
# ...

# %%
data['churn'] = data['churn'].astype('category')

data.dtypes
# Out:
# state                       object
# account length               int64
# area code                    int64
# phone number                object
# international plan          object
# voice mail plan             object
# number vmail messages        int64
# total day minutes          float64
# total day calls              int64
# total day charge           float64
# total eve minutes          float64
# total eve calls              int64
# total eve charge           float64
# total night minutes        float64
# total night calls            int64
# total night charge         float64
# total intl minutes         float64
# total intl calls             int64
# total intl charge          float64
# customer service calls       int64
# churn                     category
# dtype: object

# %%
data['churn'] = data['churn'].cat.codes

data.head(5)
# Out:
#   state  account length  area code phone number international plan  \
# 0    KS             128        415     382-4657                 no
# 1    OH             107        415     371-7191                 no
# 2    NJ             137        415     358-1921                 no
# 3    OH              84        408     375-9999                yes
# 4    OK              75        415     330-6626                yes
#
#   voice mail plan  number vmail messages  total day minutes  total day calls  \
# 0             yes                     25              265.1              110
# 1             yes                     26              161.6              123
# 2              no                      0              243.4              114
# 3              no                      0              299.4               71
# 4              no                      0              166.7              113
#
#    total day charge  ...  total eve calls  total eve charge  \
# ...

# %%
data['churn'].value_counts()
# Out:
# 0    2850
# 1     483
# Name: churn, dtype: int64

# %%
data['area code'].value_counts()
# Out:
# 415    1655
# 510     840
# 408     838
# Name: area code, dtype: int64

# %%
data['international plan'] = data['international plan'].astype('category')
data['international plan'] = data['international plan'].cat.codes

data['voice mail plan'] = data['voice mail plan'].astype('category')
data['voice mail plan'] = data['voice mail plan'].cat.codes

data.head()
# Out:
#   state  account length  area code phone number  international plan  \
# 0    KS             128        415     382-4657                   0
# 1    OH             107        415     371-7191                   0
# 2    NJ             137        415     358-1921                   0
# 3    OH              84        408     375-9999                   1
# 4    OK              75        415     330-6626                   1
#
#    voice mail plan  number vmail messages  total day minutes  total day calls  \
# 0                1                     25              265.1              110
# 1                1                     26              161.6              123
# 2                0                      0              243.4              114
# 3                0                      0              299.4               71
# 4                0                      0              166.7              113
#
#    total day charge  ...  total eve calls  total eve charge  \
# ...

# %%
data['international plan'].value_counts()
# Out:
# 0    3010
# 1     323
# Name: international plan, dtype: int64

# %%
data['voice mail plan'].value_counts()
# Out:
# 0    2411
# 1     922
# Name: voice mail plan, dtype: int64

# %%
data['state'].value_counts()
# Out:
# WV    106
# MN     84
# NY     83
# AL     80
# OR     78
# OH     78
# WI     78
# WY     77
# VA     77
# CT     74
# ID     73
# MI     73
# VT     73
# UT     72
# TX     72
# IN     71
# MD     70
# KS     70
# NC     68
# NJ     68
# MT     68
# WA     66
# NV     66
# CO     66
# RI     65
# MA     65
# MS     65
# AZ     64
# MO     63
# FL     63
# ND     62
# NM     62
# ME     62
# NE     61
# OK     61
# DE     61
# SD     60
# SC     60
# KY     59
# IL     58
# NH     56
# AR     55
# GA     54
# DC     54
# HI     53
# TN     53
# AK     52
# LA     51
# PA     45
# IA     44
# CA     34
# Name: state, dtype: int64

# %%
sns.boxplot(x='churn', y='total day minutes', data=data)

# %%
sns.boxplot(x='churn', y='customer service calls', data=data)

# %%
def bar_chart(feature):
    churn=data[data['churn']==1][feature].value_counts()
    active=data[data['churn']==0][feature].value_counts()
    df=pd.DataFrame([churn,active])
    df.index=['Churn','Active']
    df.plot(kind='bar',stacked=True, figsize=(10,5))

# %%
data["charge per intl minute"] = data['total intl charge']/data['total intl minutes']

data["charge per intl minute"]
# Out:
# 0       0.270000
# 1       0.270073
# 2       0.269672
# 3       0.269697
# 4       0.270297
#           ...
# 3328    0.269697
# 3329    0.269792
# 3330    0.270213
# 3331    0.270000
# 3332    0.270073
# Name: charge per intl minute, Length: 3333, dtype: float64

# %%
sns.boxplot(x='international plan', y='charge per intl minute', data=data)

# %%
sns.boxplot(x='international plan', y='total intl calls', data=data)

# %%
# %pip install scipy

# %%
# from scipy.stats import chi2_contingency

# list1 = [1,2,3]

# list2 = [4,5,6]

# list3 = data['churn'].tolist()

# list4 = data['state'].tolist()
# #defining the table 

# table = [list2,list3]

# stats, p, dof, expected = chi2_contingency(table)

# #interpret p-value

# alpha = 0.05

# print("p value is "+str(p))

# if p <= alpha:
#     print('Dependent on each other')
# else:
#     print("Not related to each other")

# %%
from scipy.stats import chi2_contingency

import researchpy as rp

crosstab = pd.crosstab(data['churn'],data['international plan'])

crosstab
# Out:
# international plan     0    1
# churn
# 0                   2664  186
# 1                    346  137

# %%
stat, p, dof, expected = chi2_contingency(crosstab)

#interpret p-value

alpha = 0.05

print("p value is "+str(p))

if p <= alpha:
    print('Dependent on each other')
else:
    print("Not related to each other")
# Out:
# p value is 2.4931077033159556e-50
# Dependent on each other

# %%
def ChiSquareTest(var1, var2):
    
    crosstab = pd.crosstab(data[var1],data[var2])
    stat, p, dof, expected = chi2_contingency(crosstab)
    #interpret p-value

    alpha = 0.05

    print("p value is "+str(p))

    if p <= alpha:
        print('Dependent on each other')
    else:
        print("Not related to each other")

# %%
ChiSquareTest('churn', 'international plan')
# Out:
# p value is 2.4931077033159556e-50
# Dependent on each other

# %%
data.dtypes
# Out:
# state                      object
# account length              int64
# area code                   int64
# phone number               object
# international plan           int8
# voice mail plan              int8
# number vmail messages       int64
# total day minutes         float64
# total day calls             int64
# total day charge          float64
# total eve minutes         float64
# total eve calls             int64
# total eve charge          float64
# total night minutes       float64
# total night calls           int64
# total night charge        float64
# total intl minutes        float64
# total intl calls            int64
# total intl charge         float64
# customer service calls      int64
# churn                        int8
# charge per intl minute    float64
# dtype: object

# %%
ChiSquareTest('churn', 'international plan')
# Out:
# p value is 2.4931077033159556e-50
# Dependent on each other

# %%
ChiSquareTest('churn', 'voice mail plan')
# Out:
# p value is 5.15063965903898e-09
# Dependent on each other

# %%
ChiSquareTest('churn', 'area code')
# Out:
# p value is 0.9150556960243712
# Not related to each other

# %%
ChiSquareTest('churn','state')
# Out:
# p value is 0.002296221552011188
# Dependent on each other

# %%
ChiSquareTest('churn','account length')
# Out:
# p value is 0.6859072560703084
# Not related to each other

# %%
import warnings
from pylab import rcParams
from scipy.stats import f_oneway
from scipy.stats import ttest_ind

# %%
# %matplotlib inline
warnings.filterwarnings("ignore")
rcParams['figure.figsize']=20,10
rcParams['font.size']=30
sns.set()

# %%
def plot_distribution(attribute):
    inp=data[attribute].to_numpy()
    plt.figure()
    ax=sns.distplot(inp)
    plt.axvline(np.mean(inp), color="k", linestyle="dashed", linewidth=5)
    _, max_ = plt.ylim()
    plt.text(
        inp.mean() + inp.mean() / 10,
        max_ - max_ / 10,
        "Mean: {:.2f}".format(inp.mean()),
    )
    return plt.figure

# %%
plot_distribution('total day calls')
# Out:
# <function matplotlib.pyplot.figure(num=None, figsize=None, dpi=None, facecolor=None, edgecolor=None, frameon=True, FigureClass=<class 'matplotlib.figure.Figure'>, clear=False, **kwargs)>

# %%
def plot_distribution_sidebyside(feature):
    
    arr1=data[data['churn'] == 0][feature].to_numpy()
    arr2=data[data['churn'] == 1][feature].to_numpy()
    ax1= sns.distplot(arr1)
    ax2= sns.distplot(arr2)
    plt.axvline(np.mean(arr1), color='b', linestyle='dashed', linewidth=5)
    plt.axvline(np.mean(arr2), color='orange', linestyle='dashed', linewidth=5)

# %%
data[data['churn'] == 1]['international plan'].value_counts() #Groups the 'international plan' column values on the basis of 'churn' value
type(data[data['churn'] == 1]['international plan'])
# Out:
# pandas.core.series.Series

# %%
plot_distribution_sidebyside('total day calls')

# %% [markdown]
# # Feature Engineering

# %%
data.dtypes
# Out:
# state                      object
# account length              int64
# area code                   int64
# phone number               object
# international plan           int8
# voice mail plan              int8
# number vmail messages       int64
# total day minutes         float64
# total day calls             int64
# total day charge          float64
# total eve minutes         float64
# total eve calls             int64
# total eve charge          float64
# total night minutes       float64
# total night calls           int64
# total night charge        float64
# total intl minutes        float64
# total intl calls            int64
# total intl charge         float64
# customer service calls      int64
# churn                        int8
# charge per intl minute    float64
# dtype: object

# %%
data['Total calls'] = data['total day calls'] + data['total eve calls'] + data['total night calls']

data['Total calls']
# Out:
# 0       300
# 1       329
# 2       328
# 3       248
# 4       356
#        ...
# 3328    286
# 3329    235
# 3330    258
# 3331    326
# 3332    272
# Name: Total calls, Length: 3333, dtype: int64

# %%
data['charge per minute at daytime']=data['total day charge']/data['total day minutes']
data['charge per minute at eve']=data['total eve charge']/data['total eve minutes']
data['charge per minute at night']=data['total night charge']/data['total night minutes']


data[['charge per minute at daytime','charge per minute at eve','charge per minute at night']]
# Out:
#       charge per minute at daytime  charge per minute at eve  \
# 0                         0.170011                  0.085005
# 1                         0.169988                  0.085013
# 2                         0.170008                  0.084983
# 3                         0.170007                  0.084976
# 4                         0.170006                  0.085030
# ...                            ...                       ...
# 3328                      0.169974                  0.085012
# 3329                      0.170013                  0.085007
# 3330                      0.170022                  0.085007
# 3331                      0.170019                  0.085025
# 3332                      0.170009                  0.084994
#
#       charge per minute at night
# 0                       0.044994
# 1                       0.045008
# 2                       0.045018
# 3                       0.044997
# 4                       0.044997
# ...

# %%
    data[['charge per minute at daytime','charge per minute at eve','charge per minute at night']].hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001F044BA8548>,
# ...
#       dtype=object)

# %%
data[['charge per minute at daytime','charge per minute at eve','charge per minute at night']].describe()
# Out:
#        charge per minute at daytime  charge per minute at eve  \
# count                   3331.000000               3332.000000
# mean                       0.170003                  0.085001
# std                        0.000028                  0.000016
# min                        0.169231                  0.084936
# 25%                        0.169989                  0.084988
# 50%                        0.170004                  0.085000
# 75%                        0.170017                  0.085013
# max                        0.170513                  0.085075
#
#        charge per minute at night
# count                 3333.000000
# mean                     0.045000
# std                      0.000017
# min                      0.044828
# 25%                      0.044988
# 50%                      0.045000
# 75%                      0.045013
# max                      0.045111

# %%
sns.boxplot(x='charge per minute at daytime', data=data)

# %%
def t_test(categorical,numerical):
    
    arr1=data[data[categorical]==0][numerical].to_numpy()
    arr1=arr1[np.logical_not(np.isnan(arr1))]
    arr2=data[data[categorical]==1][numerical].to_numpy()
    arr2=arr2[np.logical_not(np.isnan(arr2))]
    stat, p=ttest_ind(arr1, arr2)
    
    print('Statistics=%.3f, p=%.3f' %(stat, p))
    alpha = 0.05
    if p > alpha:
        print("Same distributions, means there exists no relationship - Null hypothesis holds")
    else:
        print("Different distributions, means there exists a relationship - Null hypothesis is rejected")

# %%
t_test('churn','Total calls')
# Out:
# Statistics=-1.134, p=0.257
# Same distributions, means there exists no relationship - Null hypothesis holds

# %%
sns.boxplot(x='churn',y='Total calls', data=data)

# %%
sns.boxplot(x='churn',y='customer service calls', data=data)

# %%
t_test('churn','customer service calls')
# Out:
# Statistics=-12.319, p=0.000
# Different distributions, means there exists a relationship - Null hypothesis is rejected

# %%
print(data[data['churn']==0]['customer service calls'].mean(), data[data['churn']==1]['customer service calls'].mean())
# Out:
# 1.4498245614035088 2.229813664596273

# %%
t_test('churn', 'charge per minute at eve')
# Out:
# Statistics=0.517, p=0.605
# Same distributions, means there exists no relationship - Null hypothesis holds

# %%
t_test('churn', 'charge per minute at night')
# Out:
# Statistics=0.174, p=0.862
# Same distributions, means there exists no relationship - Null hypothesis holds

# %%
t_test('churn', 'charge per minute at daytime')
# Out:
# Statistics=0.410, p=0.682
# Same distributions, means there exists no relationship - Null hypothesis holds

# %%
#     arr1=data[data['churn']==0][numerical].to_numpy()
#     arr2=data[data['churn']==1][numerical].to_numpy()
#     stat, p=ttest_ind(arr1, arr2)
    
#     print('Statistics=%.3f, p=%.3f' %(stat, p))
#     alpha = 0.05
#     if p > alpha:
#         print("Same distributions, means there exists no relationship - Null hypothesis holds")
#     else:
#         print("Different distributions, means there exists a relationship - Null hypothesis is rejected")

# %%
t_test('international plan', 'total intl calls')
# Out:
# Statistics=-1.002, p=0.316
# Same distributions, means there exists no relationship - Null hypothesis holds

# %%
data['charge per intl minute'].isna().sum()
# Out:
# 18

# %%
data['charge per intl minute'].isna()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3328    False
# 3329    False
# 3330    False
# 3331    False
# 3332    False
# Name: charge per intl minute, Length: 3333, dtype: bool

# %%
data['charge per intl minute']
# Out:
# 0       0.270000
# 1       0.270073
# 2       0.269672
# 3       0.269697
# 4       0.270297
#           ...
# 3328    0.269697
# 3329    0.269792
# 3330    0.270213
# 3331    0.270000
# 3332    0.270073
# Name: charge per intl minute, Length: 3333, dtype: float64

# %%
t_test('international plan', 'charge per intl minute')
# Out:
# Statistics=1.051, p=0.293
# Same distributions, means there exists no relationship - Null hypothesis holds

# %%
sns.boxplot(x='international plan',y='total intl charge', data=data)

# %%
t_test('international plan', 'total intl charge') 

#This is interesting. Those who had international plan did not pay lesser per minute of intl call
# but there exists a relationship between international plan and total intl charge
# Out:
# Statistics=-2.645, p=0.008
# Different distributions, means there exists a relationship - Null hypothesis is rejected

# %%
sns.boxplot(x='international plan',y='total intl calls', data=data)

# %%
t_test('international plan', 'total intl calls')
# Out:
# Statistics=-1.002, p=0.316
# Same distributions, means there exists no relationship - Null hypothesis holds

# %%
t_test('international plan', 'total intl minutes')
# Out:
# Statistics=-2.650, p=0.008
# Different distributions, means there exists a relationship - Null hypothesis is rejected

# %%
sns.boxplot(x='international plan',y='total intl minutes', data=data)

# %%
ChiSquareTest('international plan', 'voice mail plan')
# Out:
# p value is 0.7784680822485827
# Not related to each other

# %%
sns.boxplot(x='voice mail plan',y='number vmail messages', data=data)

# %%
t_test('voice mail plan', 'number vmail messages')
# Out:
# Statistics=-190.228, p=0.000
# Different distributions, means there exists a relationship - Null hypothesis is rejected

# %%
mask1= (data['total day minutes'] >= data['total eve minutes']) & (data['total day minutes'] >= data['total night minutes'])
mask2= (data['total eve minutes'] >= data['total day minutes']) & (data['total eve minutes'] >= data['total night minutes'])
mask3= (data['total night minutes'] >= data['total day minutes']) & (data['total night minutes'] >= data['total eve minutes'])

mask1
# Out:
# 0        True
# 1       False
# 2        True
# 3        True
# 4       False
#         ...
# 3328    False
# 3329     True
# 3330    False
# 3331     True
# 3332    False
# Length: 3333, dtype: bool

# %%
data[['total day minutes','total eve minutes','total night minutes']]
# Out:
#       total day minutes  total eve minutes  total night minutes
# 0                 265.1              197.4                244.7
# 1                 161.6              195.5                254.4
# 2                 243.4              121.2                162.6
# 3                 299.4               61.9                196.9
# 4                 166.7              148.3                186.9
# ...                 ...                ...                  ...
# 3328              156.2              215.5                279.1
# 3329              231.1              153.4                191.3
# 3330              180.8              288.8                191.9
# 3331              213.8              159.6                139.2
# 3332              234.4              265.9                241.4
#
# [3333 rows x 3 columns]

# %%
data['Time of most minutes']=  np.select([mask1, mask2, mask3], 
                            ['D','E','N'], 
                            default=np.nan)

# %%
data['Time of most minutes']
# Out:
# 0       D
# 1       N
# 2       D
# 3       D
# 4       N
#        ..
# 3328    N
# 3329    D
# 3330    E
# 3331    D
# 3332    E
# Name: Time of most minutes, Length: 3333, dtype: object

# %%
data['Time of most minutes'].value_counts()
# Out:
# N    1307
# E    1246
# D     780
# Name: Time of most minutes, dtype: int64

# %%
data.isna().sum()
# Out:
# state                            0
# account length                   0
# area code                        0
# phone number                     0
# international plan               0
# voice mail plan                  0
# number vmail messages            0
# total day minutes                0
# total day calls                  0
# total day charge                 0
# total eve minutes                0
# total eve calls                  0
# total eve charge                 0
# total night minutes              0
# total night calls                0
# total night charge               0
# total intl minutes               0
# total intl calls                 0
# total intl charge                0
# customer service calls           0
# churn                            0
# charge per intl minute          18
# Total calls                      0
# charge per minute at daytime     2
# charge per minute at eve         1
# charge per minute at night       0
# Time of most minutes             0
# ...

# %%
ChiSquareTest('churn','Time of most minutes')
# Out:
# p value is 2.0867934555429492e-10
# Dependent on each other

# %%
t_test('churn', 'Total calls')
# Out:
# Statistics=-1.134, p=0.257
# Same distributions, means there exists no relationship - Null hypothesis holds

# %%
data['Total minutes'] = data['total day minutes'] + data['total eve minutes'] + data['total night minutes']
data['Total charge'] = data['total day charge'] + data['total eve charge'] + data['total night charge']

# %%
sns.boxplot(x='churn', y='Total minutes', data=data)

# %%
t_test('churn', 'Total minutes')
# Out:
# Statistics=-11.564, p=0.000
# Different distributions, means there exists a relationship - Null hypothesis is rejected

# %%
sns.boxplot(x='churn', y='Total charge', data=data)

# %%
t_test('churn', 'Total charge')
# Out:
# Statistics=-13.450, p=0.000
# Different distributions, means there exists a relationship - Null hypothesis is rejected

# %%
data.isna().sum()
# Out:
# state                            0
# account length                   0
# area code                        0
# phone number                     0
# international plan               0
# voice mail plan                  0
# number vmail messages            0
# total day minutes                0
# total day calls                  0
# total day charge                 0
# total eve minutes                0
# total eve calls                  0
# total eve charge                 0
# total night minutes              0
# total night calls                0
# total night charge               0
# total intl minutes               0
# total intl calls                 0
# total intl charge                0
# customer service calls           0
# churn                            0
# charge per intl minute          18
# Total calls                      0
# charge per minute at daytime     2
# charge per minute at eve         1
# charge per minute at night       0
# Time of most minutes             0
# ...

# %%
data
# Out:
#      state  account length  area code phone number  international plan  \
# 0       KS             128        415     382-4657                   0
# 1       OH             107        415     371-7191                   0
# 2       NJ             137        415     358-1921                   0
# 3       OH              84        408     375-9999                   1
# 4       OK              75        415     330-6626                   1
# ...    ...             ...        ...          ...                 ...
# 3328    AZ             192        415     414-4276                   0
# 3329    WV              68        415     370-3271                   0
# 3330    RI              28        510     328-8230                   0
# 3331    CT             184        510     364-6381                   1
# 3332    TN              74        415     400-4344                   0
#
#       voice mail plan  number vmail messages  total day minutes  \
# ...

# %%
data['state'] = data['state'].astype('category')
data['state'] = data['state'].cat.codes
data
# Out:
#       state  account length  area code phone number  international plan  \
# 0        16             128        415     382-4657                   0
# 1        35             107        415     371-7191                   0
# 2        31             137        415     358-1921                   0
# 3        35              84        408     375-9999                   1
# 4        36              75        415     330-6626                   1
# ...     ...             ...        ...          ...                 ...
# 3328      3             192        415     414-4276                   0
# 3329     49              68        415     370-3271                   0
# 3330     39              28        510     328-8230                   0
# 3331      6             184        510     364-6381                   1
# 3332     42              74        415     400-4344                   0
#
#       voice mail plan  number vmail messages  total day minutes  \
# ...

# %%
ChiSquareTest('churn','phone number')
# Out:
# p value is 0.49185608455943547
# Not related to each other

# %%
data['Time of most minutes'] = data['Time of most minutes'].astype('category')
data['Time of most minutes'] = data['Time of most minutes'].cat.codes
data
# Out:
#       state  account length  area code phone number  international plan  \
# 0        16             128        415     382-4657                   0
# 1        35             107        415     371-7191                   0
# 2        31             137        415     358-1921                   0
# 3        35              84        408     375-9999                   1
# 4        36              75        415     330-6626                   1
# ...     ...             ...        ...          ...                 ...
# 3328      3             192        415     414-4276                   0
# 3329     49              68        415     370-3271                   0
# 3330     39              28        510     328-8230                   0
# 3331      6             184        510     364-6381                   1
# 3332     42              74        415     400-4344                   0
#
#       voice mail plan  number vmail messages  total day minutes  \
# ...

# %%
t_test('churn','charge per minute at daytime')
t_test('churn','charge per minute at eve')
t_test('churn','charge per minute at night')
t_test('churn','charge per intl minute')
# Out:
# Statistics=0.410, p=0.682
# Same distributions, means there exists no relationship - Null hypothesis holds
# Statistics=0.517, p=0.605
# Same distributions, means there exists no relationship - Null hypothesis holds
# Statistics=0.174, p=0.862
# Same distributions, means there exists no relationship - Null hypothesis holds
# Statistics=0.099, p=0.921
# Same distributions, means there exists no relationship - Null hypothesis holds

# %%
X=data.drop(['account length','phone number','Total calls','charge per minute at daytime','charge per minute at eve','charge per minute at night','charge per intl minute', 'area code'], axis=1)

Y=data['churn']

# %%
X
# Out:
#       state  international plan  voice mail plan  number vmail messages  \
# 0        16                   0                1                     25
# 1        35                   0                1                     26
# 2        31                   0                0                      0
# 3        35                   1                0                      0
# 4        36                   1                0                      0
# ...     ...                 ...              ...                    ...
# 3328      3                   0                1                     36
# 3329     49                   0                0                      0
# 3330     39                   0                0                      0
# 3331      6                   1                0                      0
# 3332     42                   0                1                     25
#
#       total day minutes  total day calls  total day charge  total eve minutes  \
# ...

# %%
X.dtypes
# Out:
# state                        int8
# international plan           int8
# voice mail plan              int8
# number vmail messages       int64
# total day minutes         float64
# total day calls             int64
# total day charge          float64
# total eve minutes         float64
# total eve calls             int64
# total eve charge          float64
# total night minutes       float64
# total night calls           int64
# total night charge        float64
# total intl minutes        float64
# total intl calls            int64
# total intl charge         float64
# customer service calls      int64
# churn                        int8
# Time of most minutes         int8
# Total minutes             float64
# Total charge              float64
# dtype: object

# %%
X.isna().sum()
# Out:
# state                     0
# international plan        0
# voice mail plan           0
# number vmail messages     0
# total day minutes         0
# total day calls           0
# total day charge          0
# total eve minutes         0
# total eve calls           0
# total eve charge          0
# total night minutes       0
# total night calls         0
# total night charge        0
# total intl minutes        0
# total intl calls          0
# total intl charge         0
# customer service calls    0
# churn                     0
# Time of most minutes      0
# Total minutes             0
# Total charge              0
# dtype: int64

# %%
Y
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 3328    0
# 3329    0
# 3330    0
# 3331    0
# 3332    0
# Name: churn, Length: 3333, dtype: int8

# %%
X=X.drop(['churn'], axis=1)
X
# Out:
#       state  international plan  voice mail plan  number vmail messages  \
# 0        16                   0                1                     25
# 1        35                   0                1                     26
# 2        31                   0                0                      0
# 3        35                   1                0                      0
# 4        36                   1                0                      0
# ...     ...                 ...              ...                    ...
# 3328      3                   0                1                     36
# 3329     49                   0                0                      0
# 3330     39                   0                0                      0
# 3331      6                   1                0                      0
# 3332     42                   0                1                     25
#
#       total day minutes  total day calls  total day charge  total eve minutes  \
# ...

# %%
X.corr().abs()
# Out:
#                            state  international plan  voice mail plan  \
# state                   1.000000            0.004597         0.031664
# international plan      0.004597            1.000000         0.006006
# voice mail plan         0.031664            0.006006         1.000000
# number vmail messages   0.027762            0.008745         0.956927
# total day minutes       0.006737            0.049396         0.001684
# total day calls         0.000764            0.003755         0.011086
# total day charge        0.006736            0.049398         0.001686
# total eve minutes       0.013682            0.019100         0.021545
# total eve calls         0.016268            0.006114         0.006444
# total eve charge        0.013674            0.019106         0.021559
# total night minutes     0.024576            0.028905         0.006079
# total night calls       0.007458            0.012451         0.015553
# ...

# %%
X_NoManuallyEngineeredFeatures=X.drop(['Time of most minutes','Total minutes','Total charge'], axis=1)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score

model=RandomForestClassifier(n_estimators=30)

scores=cross_val_score(model, X, Y, cv=5, scoring='f1')

print(scores.mean())

model.fit(X,Y)

scores
# Out:
# 0.8820470859993106
# array([0.8852459 , 0.82424242, 0.91304348, 0.87861272, 0.90909091])

# %%
print(model.feature_importances_)

feature_importances=pd.Series(model.feature_importances_, index=X.columns)

feature_importances.nlargest(10).plot(kind='barh')

plt.show()
# Out:
# [0.02030435 0.08323108 0.02855609 0.04165204 0.08663932 0.02404479
#  0.06019071 0.03422464 0.01894318 0.03362229 0.02794033 0.0233597
#  0.02403958 0.03254312 0.03868976 0.04088111 0.13547699 0.00773626
#  0.06677106 0.17115361]

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score

model=RandomForestClassifier(n_estimators=30, criterion='entropy')

scores=cross_val_score(model, X, Y, cv=5, scoring='f1')

print(scores.mean())

model.fit(X,Y)

scores
# Out:
# 0.8739195743647828
# array([0.87150838, 0.82424242, 0.91891892, 0.85207101, 0.90285714])

# %%
print(model.feature_importances_)

feature_importances=pd.Series(model.feature_importances_, index=X.columns)

feature_importances.nlargest(10).plot(kind='barh')

plt.show()
# Out:
# [0.02249179 0.07778336 0.02516601 0.03428045 0.07779386 0.02601862
#  0.07539954 0.03784924 0.02353242 0.03399049 0.02575294 0.0218659
#  0.02892417 0.04423866 0.05197265 0.0382362  0.12784445 0.00767437
#  0.08423101 0.13495388]

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score

model=RandomForestClassifier(n_estimators=50)

scores=cross_val_score(model, X, Y, cv=5, scoring='f1')

print(scores.mean())

model.fit(X,Y)

scores
# Out:
# 0.8873904740776879
# array([0.8839779 , 0.8452381 , 0.91891892, 0.87356322, 0.91525424])

# %%
print(model.feature_importances_)

feature_importances=pd.Series(model.feature_importances_, index=X.columns)

feature_importances.nlargest(10).plot(kind='barh')

plt.show()
# Out:
# [0.01767779 0.08313047 0.02960775 0.05015798 0.07277804 0.02406609
#  0.05878925 0.02993078 0.0206579  0.02941946 0.02502392 0.02215386
#  0.02332058 0.03514806 0.0427121  0.03589068 0.1321602  0.00707045
#  0.07007608 0.19022857]

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score

model=RandomForestClassifier(n_estimators=50, criterion='entropy')

scores=cross_val_score(model, X, Y, cv=5, scoring='f1')

print(scores.mean())

model.fit(X,Y)

scores
# Out:
# 0.8806660979180378
# array([0.87777778, 0.8313253 , 0.91304348, 0.87209302, 0.90909091])

# %%
print(model.feature_importances_)

feature_importances=pd.Series(model.feature_importances_, index=X.columns)

feature_importances.nlargest(10).plot(kind='barh')

plt.show()
# Out:
# [0.02222682 0.08944885 0.02815443 0.0368331  0.07658766 0.02649119
#  0.06481552 0.03462086 0.02414395 0.03151496 0.02553974 0.02665334
#  0.02718918 0.03878312 0.04184814 0.0366877  0.12776629 0.00821871
#  0.07465102 0.15782541]

# %%
from sklearn import tree

model = tree.DecisionTreeClassifier()

scores=cross_val_score(model, X, Y, cv=5, scoring='f1')


print(scores.mean())

model.fit(X,Y)
# Out:
# 0.7889752404786555
# DecisionTreeClassifier()

# %%
print(model.feature_importances_)

feature_importances=pd.Series(model.feature_importances_, index=X.columns)

feature_importances.nlargest(10).plot(kind='barh')

plt.show()
# Out:
# [8.25074422e-03 6.81308461e-02 9.75212884e-02 5.68748405e-03
#  6.03589077e-03 1.56096486e-02 1.55914341e-02 6.68267764e-03
#  2.47818195e-02 8.11240315e-03 1.27531584e-02 8.22676567e-03
#  1.71183131e-02 9.37334257e-02 6.78650067e-02 2.31952677e-02
#  1.07454238e-01 2.01300777e-04 1.58383013e-02 3.97209986e-01]

# %%
from sklearn import svm

model = svm.SVC()

scores=cross_val_score(model, X, Y, cv=5, scoring='f1')


print(scores.mean())

model.fit(X,Y)
# Out:
# 0.0
# SVC()

# %%
# print(model.feature_importances_)

# feature_importances=pd.Series(model.feature_importances_, index=X.columns)

# feature_importances.nlargest(10).plot(kind='barh')

# plt.show()

# %%
from sklearn.svm import LinearSVC

model = LinearSVC(random_state=0, tol=1e-5)

scores=cross_val_score(model, X, Y, cv=5, scoring='f1')


print(scores.mean())

model.fit(X,Y)
# Out:
# 0.10753059469431907
# LinearSVC(random_state=0, tol=1e-05)

# %%
# print(model.feature_importances_)

# feature_importances=pd.Series(model.feature_importances_, index=X.columns)

# feature_importances.nlargest(10).plot(kind='barh')

# plt.show()

# %%
from sklearn.naive_bayes import MultinomialNB

model = MultinomialNB()

scores=cross_val_score(model, X, Y, cv=5, scoring='f1')


print(scores.mean())

model.fit(X,Y)
# Out:
# 0.30896983169471615
# MultinomialNB()

# %%
# print(model.feature_importances_)

# feature_importances=pd.Series(model.feature_importances_, index=X.columns)

# feature_importances.nlargest(10).plot(kind='barh')

# plt.show()

# %% [markdown]
# # Feature Selection

# %% [markdown]
# ## Removing features with low variance

# %%
from sklearn.feature_selection import VarianceThreshold


def variance_threshold_select(df, thresh=0.8*(1-0.8), na_replacement=-999):
    df1 = df.copy(deep=True) # Make a deep copy of the dataframe
    selector = VarianceThreshold(threshold=thresh)
    selector.fit_transform(df1.fillna(na_replacement)) # Fill NA values as VarianceThreshold cannot deal with those
    df2 = df.loc[:,selector.get_support(indices=False)] # Get new dataframe with columns deleted that have NA values

    return df2

# %%
X_M=X 

X_M_1= variance_threshold_select(X_M)

# %%
X_M.isna().sum()
# Out:
# state                     0
# international plan        0
# voice mail plan           0
# number vmail messages     0
# total day minutes         0
# total day calls           0
# total day charge          0
# total eve minutes         0
# total eve calls           0
# total eve charge          0
# total night minutes       0
# total night calls         0
# total night charge        0
# total intl minutes        0
# total intl calls          0
# total intl charge         0
# customer service calls    0
# Time of most minutes      0
# Total minutes             0
# Total charge              0
# dtype: int64

# %%
X_M_1.isna().sum()
# Out:
# state                     0
# voice mail plan           0
# number vmail messages     0
# total day minutes         0
# total day calls           0
# total day charge          0
# total eve minutes         0
# total eve calls           0
# total eve charge          0
# total night minutes       0
# total night calls         0
# total night charge        0
# total intl minutes        0
# total intl calls          0
# total intl charge         0
# customer service calls    0
# Time of most minutes      0
# Total minutes             0
# Total charge              0
# dtype: int64

# %%
X_M_1
# Out:
#       state  voice mail plan  number vmail messages  total day minutes  \
# 0        16                1                     25              265.1
# 1        35                1                     26              161.6
# 2        31                0                      0              243.4
# 3        35                0                      0              299.4
# 4        36                0                      0              166.7
# ...     ...              ...                    ...                ...
# 3328      3                1                     36              156.2
# 3329     49                0                      0              231.1
# 3330     39                0                      0              180.8
# 3331      6                0                      0              213.8
# 3332     42                1                     25              234.4
#
#       total day calls  total day charge  total eve minutes  total eve calls  \
# ...

# %%
(X_M.shape, X_M_1.shape)
# Out:
# ((3333, 20), (3333, 19))

# %% [markdown]
# ## Select KBest

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2

Temp=SelectKBest(chi2, k=10).fit(X_M_1, Y)

Feature_Indices_Boolean_Mask=Temp.get_support() #Returns boolean mask, with TRUE values for the selected columns 

Names_Of_Selected_Features=X_M_1.columns[Feature_Indices_Boolean_Mask] #Returns name of columns that are selected 

X_M_2 = X_M_1[Names_Of_Selected_Features]

# %%
(X_M_1.shape,X_M_2.shape)
# Out:
# ((3333, 19), (3333, 10))

# %%
X_M_2
# Out:
#       voice mail plan  number vmail messages  total day minutes  \
# 0                   1                     25              265.1
# 1                   1                     26              161.6
# 2                   0                      0              243.4
# 3                   0                      0              299.4
# 4                   0                      0              166.7
# ...               ...                    ...                ...
# 3328                1                     36              156.2
# 3329                0                      0              231.1
# 3330                0                      0              180.8
# 3331                0                      0              213.8
# 3332                1                     25              234.4
#
#       total day charge  total eve minutes  total eve charge  \
# 0                45.07              197.4             16.78
# 1                27.47              195.5             16.62
# ...

# %% [markdown]
# ## Univariable Feature Selection - Generic Univariate Select

# %%
# from sklearn.feature_selection import GenericUnivariateSelect

# transformer = GenericUnivariateSelect(chi2, mode='k_best', param=20)

# Temp=transformer.fit(X_M_1, Y)

# Feature_Indices_Boolean_Mask=Temp.get_support() #Returns boolean mask, with TRUE values for the selected columns 

# Names_Of_Selected_Features=X_M_1.columns[Feature_Indices_Boolean_Mask] #Returns name of columns that are selected 

# X_M_6 = X_M_1[Names_Of_Selected_Features]

# %% [markdown]
# ## L1-based feature selection

# %%
from sklearn.svm import LinearSVC
from sklearn.feature_selection import SelectFromModel

lsvc = LinearSVC(C=0.01, penalty="l1", dual=False).fit(X_M_1, Y)
model = SelectFromModel(lsvc, prefit=True)


Feature_Indices_Boolean_Mask=model.get_support() #Returns boolean mask, with TRUE values for the selected columns 

Names_Of_Selected_Features=X_M_1.columns[Feature_Indices_Boolean_Mask] #Returns name of columns that are selected 

X_M_3 = X_M_1[Names_Of_Selected_Features]

# %%
(X_M_1.shape,X_M_3.shape)
# Out:
# ((3333, 19), (3333, 13))

# %%
X_M_3
# Out:
#       state  number vmail messages  total day minutes  total day calls  \
# 0        16                     25              265.1              110
# 1        35                     26              161.6              123
# 2        31                      0              243.4              114
# 3        35                      0              299.4               71
# 4        36                      0              166.7              113
# ...     ...                    ...                ...              ...
# 3328      3                     36              156.2               77
# 3329     49                      0              231.1               57
# 3330     39                      0              180.8              109
# 3331      6                      0              213.8              105
# 3332     42                     25              234.4              113
#
#       total eve minutes  total eve calls  total night minutes  \
# ...

# %% [markdown]
# ## Tree-based feature selection

# %%
from sklearn.ensemble import ExtraTreesClassifier

clf = ExtraTreesClassifier(n_estimators=50)
clf = clf.fit(X_M_1, Y)
clf.feature_importances_
# Out:
# array([0.03416999, 0.02994439, 0.02935139, 0.07524311, 0.03539576,
#        0.07790496, 0.04566644, 0.03137658, 0.03785548, 0.03525781,
#        0.03502475, 0.03465442, 0.03610043, 0.03812024, 0.03713616,
#        0.13725644, 0.02549623, 0.08528244, 0.13876297])

# %%
model = SelectFromModel(clf, prefit=True)

Feature_Indices_Boolean_Mask=model.get_support() #Returns boolean mask, with TRUE values for the selected columns 

Names_Of_Selected_Features=X_M_1.columns[Feature_Indices_Boolean_Mask] #Returns name of columns that are selected 

X_M_4 = X_M_1[Names_Of_Selected_Features]

# %%
(X_M_1.shape, X_M_4.shape)
# Out:
# ((3333, 19), (3333, 5))

# %%
X_M_4
# Out:
#       total day minutes  total day charge  customer service calls  \
# 0                 265.1             45.07                       1
# 1                 161.6             27.47                       1
# 2                 243.4             41.38                       0
# 3                 299.4             50.90                       2
# 4                 166.7             28.34                       3
# ...                 ...               ...                     ...
# 3328              156.2             26.55                       2
# 3329              231.1             39.29                       3
# 3330              180.8             30.74                       2
# 3331              213.8             36.35                       2
# 3332              234.4             39.85                       0
#
#       Total minutes  Total charge
# 0             707.2         72.86
# 1             611.5         55.54
# 2             527.2         59.00
# ...

# %% [markdown]
# ## Recursive Feature Selection

# %%
from sklearn.svm import SVC
from sklearn.model_selection import StratifiedKFold
from sklearn.feature_selection import RFECV

# %%
# svc = SVC(kernel="linear")
# rfecv = RFECV(estimator=svc, step=1, cv=StratifiedKFold(2), scoring='accuracy')
# rfecv.fit(X_M_1, Y)

# print("Optimal number of features : %d" % rfecv.n_features_)

# %%
# Feature_Indices_Boolean_Mask=model.get_support() #Returns boolean mask, with TRUE values for the selected columns 

# Names_Of_Selected_Features=X_M_1.columns[Feature_Indices_Boolean_Mask] #Returns name of columns that are selected 

# X_M_5 = X_M_1[Names_Of_Selected_Features]

# %%
# (X_M_1.shape, X_M_5.shape)

# %%
from sklearn.ensemble import GradientBoostingClassifier
gb = GradientBoostingClassifier(n_estimators=100)
scores = cross_val_score(gb, X_M_3, Y, cv=5, scoring='f1')
print(scores.mean())
gb.fit(X,Y)
# Out:
# 0.7494902438078578
# GradientBoostingClassifier()

# %%
gb = GradientBoostingClassifier(n_estimators=100)
scores = cross_val_score(gb, X, Y, cv=5, scoring='f1')
print(scores.mean())
gb.fit(X,Y)
# Out:
# 0.9008239589897193
# GradientBoostingClassifier()

# %%
model = GradientBoostingClassifier(n_estimators=100)
scores = cross_val_score(model, X, Y, cv=5, scoring='f1')
print(scores.mean())
model.fit(X,Y)
# Out:
# 0.9008239589897193
# GradientBoostingClassifier()

# %%
print(model.feature_importances_)

feature_importances=pd.Series(model.feature_importances_, index=X.columns)

feature_importances.nlargest(10).plot(kind='barh')

plt.show()
# Out:
# [1.66366695e-03 1.17197260e-01 7.43116479e-02 5.08820408e-02
#  2.57167852e-03 1.70073517e-03 2.99082460e-03 1.03658841e-03
#  8.09663903e-04 1.50187491e-03 3.02768082e-03 1.25948034e-03
#  1.66183877e-03 3.40589825e-02 6.71504799e-02 4.32790117e-02
#  1.29513328e-01 3.85987819e-04 4.08476638e-03 4.60912462e-01]

# %%
model = GradientBoostingClassifier(n_estimators=100)
scores = cross_val_score(model, X, Y, cv=5, scoring='f1')
print(scores.mean())
model.fit(X_M_1,Y)
# Out:
# 0.8998349416819164
# GradientBoostingClassifier()

# %%
model = GradientBoostingClassifier(n_estimators=100)
scores = cross_val_score(model, X, Y, cv=5, scoring='f1')
print(scores.mean())
model.fit(X_M_2,Y)
# Out:
# 0.8985077715168481
# GradientBoostingClassifier()

# %%
model = GradientBoostingClassifier(n_estimators=100)
scores = cross_val_score(model, X, Y, cv=5, scoring='f1')
print(scores.mean())
model.fit(X_M_4,Y)
# Out:
# 0.89885418438831
# GradientBoostingClassifier()
